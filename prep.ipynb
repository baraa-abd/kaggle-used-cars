# %% [markdown]
# Import needed libraries:

# %%
import pandas as pd
import re
import os
import time
import reliability_and_inflation as ri 
import enrich_with_type_msrp as enrich
import google.generativeai as genai

only_alphanum = re.compile(r'[\W_]+')  #regular expression pattern to remove any non-alphanumeric characters
genai.configure(api_key = os.environ.get("GEMINI_API_KEY"))

# %% [markdown]
# # 1- Preparing the data:

# %% [markdown]
# Load datasets:

# %%
cars_train = pd.read_csv("train.csv")
cars_test = pd.read_csv("test.csv")

# %% [markdown]
# First, we use our Google Gemini-based model to add columns "body_style" and "original_msrp" to our data:

# %% [markdown]
# The parameters:

# %%
model = genai.GenerativeModel("tunedModels/finetunedmodelcartypemsrpv1-19pkfyc97yiq", generation_config = {"temperature":0.1})
known_cars = pd.read_csv("list_of_examples.csv")
known_cars.rename(columns={"body_style":"body", "MSRP":"msrp"}, inplace=True)
batch_size = 60    #might have to be fixed based on tuned model
rounds = 5   #number of times each batch is asked about. Should be an odd number
possible_body_types = set(known_cars['body'].unique())
prompt_params = {"min_num":4, "max_num":8, "repeats":False,
                 "min_len":3, "max_len":10, "balance":True,
                 "type_size":None}

# %% [markdown]
# We run the model:

# %%
#Splitting into pieces so that we save after each piece
car_names = enrich.get_car_keys_names([cars_train, cars_test])
car_names_df = pd.DataFrame.from_dict(car_names, orient='index').reset_index()
total = len(car_names_df)
n=8
dfs = [car_names_df.iloc[(i*total)//n:((i+1)*total)//n] for i in range(n)]

for i in range(len(dfs)):
    dfs[i].to_csv("car_keys_slice_"+str(i+1)+".csv", index=False)
# Out:
# Total unique specific car models =  28070

# %%
#car_names = enrich.get_car_keys_names([cars_train, cars_test])
for i in range(6, 9):   #Done 1-5. Need to do 6-8
    print(f"Working on slice {i}")
    read_dict = pd.read_csv(f"car_keys_slice_{i}.csv").to_dict('index')
    car_names = {read_dict[i]['index']:read_dict[i]['0'] for i in read_dict}
    car_body_types, car_msrps = enrich.enrich_using_model(model, car_names, known_cars, batch_size,
                                                            possible_body_types, prompt_params, 
                                                            rounds = rounds)


    car_body_types_df = pd.DataFrame.from_dict(car_body_types, orient='index').reset_index()
    car_msrps_df = pd.DataFrame.from_dict(car_msrps, orient='index').reset_index()

    car_body_types_df.to_csv(f"car_body_types_slice_{i}.csv", index=False)
    car_msrps_df.to_csv(f"car_msrps_slice_{i}.csv", index=False)
# Out:
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 59
# num answers = 57
# num answers = 60
# num answers = 59
# num answers = 60
# 3480
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 3509
# Working on slice 7
# Using genai.GenerativeModel(
#     model_name='tunedModels/finetunedmodelcartypemsrpv1-19pkfyc97yiq',
#     generation_config={'temperature': 0.1},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# ):
# Parameters:
# Batch size = 60
# Total number of car models = 3509
# Min # of examples in each prompt = 4      Max # of examples in each prompt = 8
# Min length of examples in each prompt = 3      Max length of examples in each prompt = 10
# Allow repeats in each prompt example = False       Number of times each batch is asked about = 5
#
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 55
# num answers = 60
# num answers = 60
# 120
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# 180
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 240
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# 300
# num answers = 57
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 360
# num answers = 60
# num answers = 59
# num answers = 59
# num answers = 60
# num answers = 36
# num answers = 61
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# 420
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 480
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 540
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 600
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 59
# num answers = 60
# 660
# num answers = 60
# num answers = 60
# num answers = 50
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# 720
# num answers = 59
# num answers = 60
# num answers = 58
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 780
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# Problem in batch 13. Trying again...
# num answers = 58
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 49
# num answers = 60
# num answers = 60
# Problem in batch 13. Trying again...
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# Problem in batch 13. Trying again...
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 840
# num answers = 59
# num answers = 58
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# Problem in batch 14. Trying again...
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 900
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 960
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 53
# num answers = 60
# 1020
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 1080
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 1140
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 1200
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 19
# num answers = 60
# 1260
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# 1320
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 35
# num answers = 60
# 1380
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 1440
# num answers = 60
# num answers = 60
# num answers = 58
# num answers = 60
# num answers = 60
# num answers = 60
# 1500
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# 1560
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 1620
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# 1680
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 1740
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# 1800
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 1860
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 58
# num answers = 60
# 1920
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# 1980
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 2040
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 2100
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 56
# num answers = 60
# num answers = 60
# 2160
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 58
# num answers = 60
# 2220
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# 2280
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 2340
# num answers = 60
# num answers = 60
# num answers = 29
# num answers = 60
# num answers = 60
# num answers = 60
# 2400
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# Problem in batch 40. Trying again...
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 2460
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 2520
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 2580
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 2640
# num answers = 60
# num answers = 58
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 2700
# num answers = 59
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 57
# num answers = 60
# num answers = 59
# num answers = 60
# 2760
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# 2820
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 2880
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 2940
# num answers = 60
# num answers = 57
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# Problem in batch 49. Trying again...
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# 3000
# num answers = 35
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 3060
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# Problem in batch 51. Trying again...
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 3120
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 55
# num answers = 60
# num answers = 60
# 3180
# num answers = 60
# num answers = 58
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 3240
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 3300
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 3360
# num answers = 57
# num answers = 60
# num answers = 33
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 3420
# num answers = 60
# num answers = 55
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 58
# num answers = 60
# 3480
# num answers = 2
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 3509
# Working on slice 8
# Using genai.GenerativeModel(
#     model_name='tunedModels/finetunedmodelcartypemsrpv1-19pkfyc97yiq',
#     generation_config={'temperature': 0.1},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# ):
# Parameters:
# Batch size = 60
# Total number of car models = 3509
# Min # of examples in each prompt = 4      Max # of examples in each prompt = 8
# Min length of examples in each prompt = 3      Max length of examples in each prompt = 10
# Allow repeats in each prompt example = False       Number of times each batch is asked about = 5
#
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 60
# num answers = 60
# num answers = 59
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 64
# num answers = 60
# num answers = 60
# 120
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 180
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 240
# num answers = 60
# num answers = 60
# num answers = 58
# num answers = 60
# num answers = 60
# num answers = 60
# 300
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 360
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 54
# num answers = 60
# 420
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# 480
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 540
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 600
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 660
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 720
# num answers = 58
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 780
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# 840
# num answers = 60
# num answers = 58
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 900
# num answers = 60
# num answers = 58
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# 960
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# 1020
# num answers = 60
# num answers = 59
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# Problem in batch 17. Trying again...
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# Problem in batch 17. Trying again...
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# Problem in batch 17. Trying again...
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# Problem in batch 17. Trying again...
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 1080
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 1140
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# 1200
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# 1260
# num answers = 60
# num answers = 60
# num answers = 58
# num answers = 45
# num answers = 60
# num answers = 60
# num answers = 60
# 1320
# num answers = 60
# num answers = 60
# num answers = 55
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# 1380
# num answers = 58
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 55
# num answers = 59
# num answers = 60
# 1440
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 1500
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 58
# num answers = 60
# num answers = 60
# 1560
# num answers = 56
# num answers = 60
# num answers = 29
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 1620
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 1680
# num answers = 42
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 1740
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 1800
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 1860
# num answers = 60
# num answers = 30
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 1920
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 57
# num answers = 60
# 1980
# num answers = 60
# num answers = 59
# num answers = 59
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 58
# num answers = 60
# 2040
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 2100
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# 2160
# num answers = 60
# num answers = 58
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# 2220
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# Problem in batch 37. Trying again...
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# Problem in batch 37. Trying again...
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 2280
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 2340
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 47
# num answers = 60
# num answers = 54
# num answers = 60
# 2400
# num answers = 60
# num answers = 59
# num answers = 58
# num answers = 59
# num answers = 57
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# 2460
# num answers = 56
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 2520
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 58
# num answers = 59
# num answers = 60
# num answers = 60
# 2580
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# 2640
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 2700
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 2760
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# Problem in batch 46. Trying again...
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 2820
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 54
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# 2880
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 2940
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# Problem in batch 49. Trying again...
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 3000
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 48
# num answers = 46
# num answers = 59
# num answers = 59
# num answers = 60
# num answers = 60
# 3060
# num answers = 31
# num answers = 55
# num answers = 59
# num answers = 59
# num answers = 60
# num answers = 43
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# 3120
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 3180
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 57
# num answers = 60
# num answers = 60
# 3240
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# num answers = 60
# num answers = 60
# Problem in batch 54. Trying again...
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 58
# num answers = 60
# num answers = 60
# 3300
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 3360
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 3420
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# 3480
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 60
# num answers = 59
# num answers = 60
# 3509

# %%
#combine results from slices
n= 8
car_body_types_read = pd.concat([pd.read_csv("car_body_types_slice_"+str(i+1)+".csv") for i in range(n)]).reset_index().to_dict('index')
car_msrps_read = pd.concat([pd.read_csv("car_msrps_slice_"+str(i+1)+".csv") for i in range(n)]).reset_index().to_dict('index')

car_body_types = {car_body_types_read[i]['index']:car_body_types_read[i]['0'] for i in car_body_types_read}
car_msrps = {car_msrps_read[i]['index']:car_msrps_read[i]['0'] for i in car_msrps_read}

# %% [markdown]
# We use the resulting data to add our new columns:

# %%
enrich.update_car_type_msrp([cars_train, cars_test], car_body_types, car_msrps)

# %% [markdown]
# Fill missing values in accident and clean_title columns:

# %%
missing_fill = {"accident": "unknown", "clean_title": "no", 
                "int_col": "unknown", "ext_col": "unknown",
                "engine": "unknown", "transmission": "unknown", "fuel_type": "unknown"}
cars_train.fillna(value=missing_fill, inplace=True)   #fill missing values
cars_test.fillna(value=missing_fill, inplace=True)

# %% [markdown]
# Remove any non-alphanumeric characters from columns with string input and change into lowercase:

# %%
cat_types = ["model", "brand", "ext_col", "int_col", "accident", 
             "clean_title", "full_name", "brand_model", "body_style",
             'engine','transmission','fuel_type']
for col in cat_types:
    cars_train[col] = cars_train[col].apply(lambda x: only_alphanum.sub("", x).lower())
    cars_test[col] = cars_test[col].apply(lambda x: only_alphanum.sub("", x).lower())

cars_train = cars_train.mask(cars_train == '')  #replace empty cells with NaN
cars_test = cars_test.mask(cars_test == '')
cars_train.fillna(value=missing_fill, inplace=True)   #refill missing values
cars_test.fillna(value=missing_fill, inplace=True)

# %% [markdown]
# Add "age" as a column:

# %%
cars_train["age"]=2025-cars_train["model_year"]
cars_test["age"]=2025-cars_test["model_year"]

# %% [markdown]
# Convert accident and clean_title into 0 or 1 values:

# %%
cars_train['accident'] = cars_train['accident'].apply(lambda x: 0 if x == 'nonereported' else 1)
cars_test['accident'] = cars_test['accident'].apply(lambda x: 0 if x == 'nonereported' else 1)

cars_train['clean_title'] = cars_train['clean_title'].apply(lambda x: 0 if x == 'no' else 1)
cars_test['clean_title'] = cars_test['clean_title'].apply(lambda x: 0 if x == 'no' else 1)

# %% [markdown]
# Add a column "reliability" with a normalized reliability score based on brand:

# %%
reliability_dict = ri.build_reliability_dict()
cars_train['reliability'] = cars_train['brand'].apply(lambda x: ri.get_reliability(x, reliability_dict))
cars_test['reliability'] = cars_test['brand'].apply(lambda x: ri.get_reliability(x, reliability_dict))

# %% [markdown]
# We then add a column where we adjust the original msrp to 2024 dollars:

# %%
ri.adjust_for_inflation(cars_train, 'model_year', 'msrp', 2024)
ri.adjust_for_inflation(cars_test, 'model_year', 'msrp', 2024)

# %% [markdown]
# We add columns for the difference between the original and adjusted msrp on one hand and price on the other. These are to be tested as regression targets from which we can recover price.

# %%
cars_train['price_diff'] = cars_train['price']-cars_train['msrp']
cars_train['adjusted_price_diff'] = cars_train['price']-cars_train['adjusted_msrp']

# %% [markdown]
# We standardize color names a bit

# %%
def standardize_color(color, standard_colors = []):
    color = color.replace("grey", "gray")
    color = color.replace("obsidian", "black")
    color = color.replace("ebony", "black")
    color = color.replace("pearl", "white")
    for s_col in standard_colors:
        if color.find(s_col) != -1:
            return s_col
    return color

color_counts_ext = cars_train['ext_col'].value_counts()
standard_colors_ext = list(color_counts_ext[color_counts_ext>800].keys())
standard_colors_ext = [standardize_color(c, standard_colors = standard_colors_ext) for c in standard_colors_ext]

color_counts_int = cars_train['int_col'].value_counts()
standard_colors_int = list(color_counts_int[color_counts_int>500].keys())
standard_colors_int = [standardize_color(c, standard_colors = standard_colors_int) for c in standard_colors_int]

standard_colors = list(set(standard_colors_int + standard_colors_ext))
print(standard_colors)
for col in ['ext_col', 'int_col']:
    cars_train[col] = cars_train[col].apply(lambda x: standardize_color(x, standard_colors = standard_colors))
    cars_test[col] = cars_test[col].apply(lambda x: standardize_color(x, standard_colors = standard_colors))
# Out:
# ['gold', 'black', 'gray', 'unknown', 'silver', 'brown', 'beige', 'yellow', 'orange', 'red', 'blue', 'white', 'green']

# %%
# use the gemini api to ask about which standard color is closest to a given color
model = genai.GenerativeModel("gemini-1.5-flash-002", generation_config = {"temperature":0.05})
color_dict = {col:col for color in standard_colors}
color_counts_ext = cars_train['ext_col'].value_counts()
color_counts_int = cars_train['int_col'].value_counts()
all_colors = list(set(list(color_counts_ext.keys())+list(color_counts_int.keys())))
for color in all_colors:
    if color in color_dict or color=='unknown': continue
    done = False
    while not done:
        try:
            prompt = f"Of the colors {standard_colors},which is the closest to {color}? If none are at all similar, just respond with {color}. Give your answer as just the color without any other words or punctuation. Make sure your answer is either a color from the list or {color} itself."
            answer = model.generate_content(prompt).text
            color_dict[color] = only_alphanum.sub("", answer).lower()
            print(color, color_dict[color])
            time.sleep(4)
            done = True
        except:
            time.sleep(4)
print(color_dict)
# Out:
# cloud white
# richgarnetmetallic red
# scarletember red
# hotspur red
# darkgraphitemetallic gray
# cc cc
# grigionimbus gray
# brandy brown
# slate gray
# deepcypress green
# satinsteelmetallic silver
# linen beige
# metallic silver
# saharatan beige
# platinum silver
# riftmetallic silver
# charcoal gray
# amber gold
# granitecrystalmetallicclearcoat gray
# graphitewgunmetal gray
# mediumstone beige
# darkgalvanized gray
# tempest gray
# camel brown
# iridiummetallic silver
# biancoisis white
# platinumquartzmetallic silver
# darksapphire black
# macchiato beige
# purple purple
# sandstone beige
# portland gray
# ametrinmetallic ametrinmetallic
# granitecrystalclearcoatmetallic gray
# maroon red
# lightslate gray
# mocha brown
# billetclearcoatmetallic silver
# moonlightcloud silver
# neroade black
# verde green
# sandstonemetallic beige
# black gray
# magneticmetallic silver
# nero black
# customcolor pleaseprovidethevalueofcustomcolor
# bronzedunemetallic brown
# darkmattermetallic black
# majesticplummetallic purple
# gideon gideon
# maximumsteelmetallic gray
# navypier blue
# shale gray
# caramel brown
# giallotaurusneroade yellow
# chalk white
# white beige
# pink red
# burnishedbronzemetallic brown
# red red
# designomagnomatte brown
# gomango orange
# sunsetdriftchromaflair orange
# gray silver
# espresso brown
# camelleather brown
# mediumdarkslate gray
# darkash gray
# hellayellaclearcoat yellow
# porpoise gray
# mesa brown
# blk black
# walnut brown
# nerodaytona brown
# glacier white
# brown beige
# parchment beige
# chestnut brown
# oysterwcontrast beige
# silver gray
# deepgarnet red
# nightfallmica black
# ice white
# onyx black
# granite gray
# yellow gold
# biancopolar white
# hotspurhide brown
# tupelo brown
# cocoadune brown
# manhattannoirmetallic black
# ash gray
# deepchestnut brown
# biancomonocerus white
# tension gold
# orange red
# tungstenmetallic silver
# roast brown
# yulong beige
# graphite gray
# beluga white
# tan beige
# anthracite gray
# darkauburn brown
# neronoctis black
# lunarrock gray
# darkmoss green
# belugahide gray
# orchid purple
# cappuccino beige
# biancoicarusmetallic silver
# gold yellow
# gunmetallic gray
# mediumlightcamel beige
# sport sport
# arancioborealis orange
# beige beige
# darkashmetallic gray
# rossocorsa red
# chateau brown
# verylightcashmere beige
# rossomarsmetallic brown
# ceramic beige
# green green
# mountainairmetallic silver
# blu blue
# stormysea blue
# rosso red
# darkslatemetallic gray
# blue blue
# boulder brown
# mediumpewter gray
# caviar black
# liquidplatinum silver
# lighttitanium silver
# {'int_col': 'int_col', 'cloud': 'white', 'richgarnetmetallic': 'red', 'scarletember': 'red', 'hotspur': 'red', 'darkgraphitemetallic': 'gray', 'cc': 'cc', 'grigionimbus': 'gray', 'brandy': 'brown', 'slate': 'gray', 'deepcypress': 'green', 'satinsteelmetallic': 'silver', 'linen': 'beige', 'metallic': 'silver', 'saharatan': 'beige', 'platinum': 'silver', 'riftmetallic': 'silver', 'charcoal': 'gray', 'amber': 'gold', 'granitecrystalmetallicclearcoat': 'gray', 'graphitewgunmetal': 'gray', 'mediumstone': 'beige', 'darkgalvanized': 'gray', 'tempest': 'gray', 'camel': 'brown', 'iridiummetallic': 'silver', 'biancoisis': 'white', 'platinumquartzmetallic': 'silver', 'darksapphire': 'black', 'macchiato': 'beige', 'purple': 'purple', 'sandstone': 'beige', 'portland': 'gray', 'ametrinmetallic': 'ametrinmetallic', 'granitecrystalclearcoatmetallic': 'gray', 'maroon': 'red', 'lightslate': 'gray', 'mocha': 'brown', 'billetclearcoatmetallic': 'silver', 'moonlightcloud': 'silver', 'neroade': 'black', 'verde': 'green', 'sandstonemetallic': 'beige', 'black': 'gray', 'magneticmetallic': 'silver', 'nero': 'black', 'customcolor': 'pleaseprovidethevalueofcustomcolor', 'bronzedunemetallic': 'brown', 'darkmattermetallic': 'black', 'majesticplummetallic': 'purple', 'gideon': 'gideon', 'maximumsteelmetallic': 'gray', 'navypier': 'blue', 'shale': 'gray', 'caramel': 'brown', 'giallotaurusneroade': 'yellow', 'chalk': 'white', 'white': 'beige', 'pink': 'red', 'burnishedbronzemetallic': 'brown', 'red': 'red', 'designomagnomatte': 'brown', 'gomango': 'orange', 'sunsetdriftchromaflair': 'orange', 'gray': 'silver', 'espresso': 'brown', 'camelleather': 'brown', 'mediumdarkslate': 'gray', 'darkash': 'gray', 'hellayellaclearcoat': 'yellow', 'porpoise': 'gray', 'mesa': 'brown', 'blk': 'black', 'walnut': 'brown', 'nerodaytona': 'brown', 'glacier': 'white', 'brown': 'beige', 'parchment': 'beige', 'chestnut': 'brown', 'oysterwcontrast': 'beige', 'silver': 'gray', 'deepgarnet': 'red', 'nightfallmica': 'black', 'ice': 'white', 'onyx': 'black', 'granite': 'gray', 'yellow': 'gold', 'biancopolar': 'white', 'hotspurhide': 'brown', 'tupelo': 'brown', 'cocoadune': 'brown', 'manhattannoirmetallic': 'black', 'ash': 'gray', 'deepchestnut': 'brown', 'biancomonocerus': 'white', 'tension': 'gold', 'orange': 'red', 'tungstenmetallic': 'silver', 'roast': 'brown', 'yulong': 'beige', 'graphite': 'gray', 'beluga': 'white', 'tan': 'beige', 'anthracite': 'gray', 'darkauburn': 'brown', 'neronoctis': 'black', 'lunarrock': 'gray', 'darkmoss': 'green', 'belugahide': 'gray', 'orchid': 'purple', 'cappuccino': 'beige', 'biancoicarusmetallic': 'silver', 'gold': 'yellow', 'gunmetallic': 'gray', 'mediumlightcamel': 'beige', 'sport': 'sport', 'arancioborealis': 'orange', 'beige': 'beige', 'darkashmetallic': 'gray', 'rossocorsa': 'red', 'chateau': 'brown', 'verylightcashmere': 'beige', 'rossomarsmetallic': 'brown', 'ceramic': 'beige', 'green': 'green', 'mountainairmetallic': 'silver', 'blu': 'blue', 'stormysea': 'blue', 'rosso': 'red', 'darkslatemetallic': 'gray', 'blue': 'blue', 'boulder': 'brown', 'mediumpewter': 'gray', 'caviar': 'black', 'liquidplatinum': 'silver', 'lighttitanium': 'silver'}
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[24], line 22
#      20 print(color_dict)
#      21 for col in ['ext_col', 'int_col']:
# ---> 22     cars_train[col] = cars_train[col].apply(color_dict)
#      23     cars_test[col] = cars_test[col].apply(color_dict)
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/pandas/core/series.py:4764, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4629 def apply(
#    4630     self,
#    4631     func: AggFuncType,
#    (...)
#    4636     **kwargs,
#    4637 ) -> DataFrame | Series:
#    4638     """
#    4639     Invoke function on values of Series.
#    4640
#    (...)
#    4755     dtype: float64
#    4756     """
#    4757     return SeriesApply(
#    4758         self,
#    4759         func,
#    4760         convert_dtype=convert_dtype,
#    4761         by_row=by_row,
#    4762         args=args,
#    4763         kwargs=kwargs,
# -> 4764     ).apply()
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/pandas/core/apply.py:1199, in SeriesApply.apply(self)
#    1197 # dispatch to handle list-like or dict-like
#    1198 if is_list_like(self.func):
# -> 1199     return self.apply_list_or_dict_like()
#    1201 if isinstance(self.func, str):
#    1202     # if we are a string, try to dispatch
#    1203     return self.apply_str()
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/pandas/core/apply.py:604, in Apply.apply_list_or_dict_like(self)
#     601 kwargs = self.kwargs
#     603 if is_dict_like(func):
# --> 604     result = self.agg_or_apply_dict_like(op_name="apply")
#     605 else:
#     606     result = self.agg_or_apply_list_like(op_name="apply")
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/pandas/core/apply.py:739, in NDFrameApply.agg_or_apply_dict_like(self, op_name)
#     736     raise NotImplementedError("axis other than 0 is not supported")
#     738 selection = None
# --> 739 result_index, result_data = self.compute_dict_like(
#     740     op_name, obj, selection, kwargs
#     741 )
#     742 result = self.wrap_results_dict_like(obj, result_index, result_data)
#     743 return result
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/pandas/core/apply.py:455, in Apply.compute_dict_like(self, op_name, selected_obj, selection, kwargs)
#     452 if selected_obj.ndim == 1:
#     453     # key only used for output
#     454     colg = obj._gotitem(selection, ndim=1)
# --> 455     results = [getattr(colg, op_name)(how, **kwargs) for _, how in func.items()]
#     456     keys = list(func.keys())
#     457 elif not is_groupby and is_non_unique_col:
#     458     # key used for column selection and output
#     459     # GH#51099
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/pandas/core/apply.py:455, in <listcomp>(.0)
#     452 if selected_obj.ndim == 1:
#     453     # key only used for output
#     454     colg = obj._gotitem(selection, ndim=1)
# --> 455     results = [getattr(colg, op_name)(how, **kwargs) for _, how in func.items()]
#     456     keys = list(func.keys())
#     457 elif not is_groupby and is_non_unique_col:
#     458     # key used for column selection and output
#     459     # GH#51099
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/pandas/core/series.py:4764, in Series.apply(self, func, convert_dtype, args, by_row, **kwargs)
#    4629 def apply(
#    4630     self,
#    4631     func: AggFuncType,
#    (...)
#    4636     **kwargs,
#    4637 ) -> DataFrame | Series:
#    4638     """
#    4639     Invoke function on values of Series.
#    4640
#    (...)
#    4755     dtype: float64
#    4756     """
#    4757     return SeriesApply(
#    4758         self,
#    4759         func,
#    4760         convert_dtype=convert_dtype,
#    4761         by_row=by_row,
#    4762         args=args,
#    4763         kwargs=kwargs,
# -> 4764     ).apply()
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/pandas/core/apply.py:1203, in SeriesApply.apply(self)
#    1199     return self.apply_list_or_dict_like()
#    1201 if isinstance(self.func, str):
#    1202     # if we are a string, try to dispatch
# -> 1203     return self.apply_str()
#    1205 if self.by_row == "_compat":
#    1206     return self.apply_compat()
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/pandas/core/apply.py:586, in Apply.apply_str(self)
#     584         else:
#     585             self.kwargs["axis"] = self.axis
# --> 586 return self._apply_str(obj, func, *self.args, **self.kwargs)
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/pandas/core/apply.py:682, in Apply._apply_str(self, obj, func, *args, **kwargs)
#     680 else:
#     681     msg = f"'{func}' is not a valid function for '{type(obj).__name__}' object"
# --> 682     raise AttributeError(msg)
#
# AttributeError: 'int_col' is not a valid function for 'Series' object

# %%
for color in standard_colors:
    color_dict[color] = color

# %%
color_dict
# Out:
# {'int_col': 'int_col',
#  'cloud': 'white',
#  'richgarnetmetallic': 'red',
#  'scarletember': 'red',
#  'hotspur': 'red',
#  'darkgraphitemetallic': 'gray',
#  'cc': 'cc',
#  'grigionimbus': 'gray',
#  'brandy': 'brown',
#  'slate': 'gray',
#  'deepcypress': 'green',
#  'satinsteelmetallic': 'silver',
#  'linen': 'beige',
#  'metallic': 'silver',
#  'saharatan': 'beige',
#  'platinum': 'silver',
#  'riftmetallic': 'silver',
#  'charcoal': 'gray',
#  'amber': 'gold',
#  'granitecrystalmetallicclearcoat': 'gray',
#  'graphitewgunmetal': 'gray',
#  'mediumstone': 'beige',
#  'darkgalvanized': 'gray',
#  'tempest': 'gray',
#  'camel': 'brown',
#  'iridiummetallic': 'silver',
#  'biancoisis': 'white',
#  'platinumquartzmetallic': 'silver',
#  'darksapphire': 'black',
#  'macchiato': 'beige',
#  'purple': 'purple',
#  'sandstone': 'beige',
#  'portland': 'gray',
#  'ametrinmetallic': 'ametrinmetallic',
#  'granitecrystalclearcoatmetallic': 'gray',
#  'maroon': 'red',
#  'lightslate': 'gray',
#  'mocha': 'brown',
#  'billetclearcoatmetallic': 'silver',
#  'moonlightcloud': 'silver',
#  'neroade': 'black',
#  'verde': 'green',
#  'sandstonemetallic': 'beige',
#  'black': 'black',
#  'magneticmetallic': 'silver',
#  'nero': 'black',
#  'customcolor': 'pleaseprovidethevalueofcustomcolor',
#  'bronzedunemetallic': 'brown',
#  'darkmattermetallic': 'black',
#  'majesticplummetallic': 'purple',
#  'gideon': 'gideon',
#  'maximumsteelmetallic': 'gray',
#  'navypier': 'blue',
#  'shale': 'gray',
#  'caramel': 'brown',
#  'giallotaurusneroade': 'yellow',
#  'chalk': 'white',
#  'white': 'white',
#  'pink': 'red',
#  'burnishedbronzemetallic': 'brown',
#  'red': 'red',
#  'designomagnomatte': 'brown',
#  'gomango': 'orange',
#  'sunsetdriftchromaflair': 'orange',
#  'gray': 'gray',
#  'espresso': 'brown',
#  'camelleather': 'brown',
#  'mediumdarkslate': 'gray',
#  'darkash': 'gray',
#  'hellayellaclearcoat': 'yellow',
#  'porpoise': 'gray',
#  'mesa': 'brown',
#  'blk': 'black',
#  'walnut': 'brown',
#  'nerodaytona': 'brown',
#  'glacier': 'white',
#  'brown': 'brown',
#  'parchment': 'beige',
#  'chestnut': 'brown',
#  'oysterwcontrast': 'beige',
#  'silver': 'silver',
#  'deepgarnet': 'red',
#  'nightfallmica': 'black',
#  'ice': 'white',
#  'onyx': 'black',
#  'granite': 'gray',
#  'yellow': 'yellow',
#  'biancopolar': 'white',
#  'hotspurhide': 'brown',
#  'tupelo': 'brown',
#  'cocoadune': 'brown',
#  'manhattannoirmetallic': 'black',
#  'ash': 'gray',
#  'deepchestnut': 'brown',
#  'biancomonocerus': 'white',
#  'tension': 'gold',
#  'orange': 'orange',
#  'tungstenmetallic': 'silver',
#  'roast': 'brown',
#  'yulong': 'beige',
#  'graphite': 'gray',
#  'beluga': 'white',
#  'tan': 'beige',
#  'anthracite': 'gray',
#  'darkauburn': 'brown',
#  'neronoctis': 'black',
#  'lunarrock': 'gray',
#  'darkmoss': 'green',
#  'belugahide': 'gray',
#  'orchid': 'purple',
#  'cappuccino': 'beige',
#  'biancoicarusmetallic': 'silver',
#  'gold': 'gold',
#  'gunmetallic': 'gray',
#  'mediumlightcamel': 'beige',
#  'sport': 'sport',
#  'arancioborealis': 'orange',
#  'beige': 'beige',
#  'darkashmetallic': 'gray',
#  'rossocorsa': 'red',
#  'chateau': 'brown',
#  'verylightcashmere': 'beige',
#  'rossomarsmetallic': 'brown',
#  'ceramic': 'beige',
#  'green': 'green',
#  'mountainairmetallic': 'silver',
#  'blu': 'blue',
#  'stormysea': 'blue',
#  'rosso': 'red',
#  'darkslatemetallic': 'gray',
#  'blue': 'blue',
#  'boulder': 'brown',
#  'mediumpewter': 'gray',
#  'caviar': 'black',
#  'liquidplatinum': 'silver',
#  'lighttitanium': 'silver',
#  'unknown': 'unknown'}

# %%
for col in ['ext_col', 'int_col']:
    cars_train[col] = cars_train[col].apply(lambda x: color_dict[x])
    cars_test[col] = cars_test[col].apply(lambda x: color_dict[x])

# %% [markdown]
# Indicate that infrequent categorical values are probably mistakes or typos:

# %%
threshold = 25
for cat in cat_types:
    value_counts = cars_train[cat].value_counts().to_dict()
    cars_train[cat] = cars_train[cat].apply(lambda x: x if value_counts[x] > threshold else "unknown")
    cars_test[cat] = cars_test[cat].apply(lambda x: x if (x in value_counts) and (value_counts[x] > threshold) else "unknown")

# %% [markdown]
# We indicate which columns are categorical.

# %%
cars_train = cars_train.astype({col: "category" for col in cat_types})
cars_test = cars_test.astype({col: "category" for col in cat_types})

# %% [markdown]
# Drop unwanted columns:

# %%
drop_cols = []       #list of columns to drop
cars_train.drop(columns=drop_cols, inplace=True)
cars_test.drop(columns=drop_cols, inplace=True)

# %%
cars_train.to_csv("train_processed.csv", index=False)
cars_test.to_csv("test_processed.csv", index=False)

# %% [markdown]
# # 2- XGBoost and Random Forest

# %% [markdown]
# Import the needed libraries:

# %%
import sklearn as sk
import xgboost as xgb
import multiprocessing

# %%
X = cars_train.loc[:,cars_train.columns != 'price']
y = cars_train['price']
X
# Out:
#       id         brand                    model  model_year  milage  \
# 0      0          mini              coopersbase        2007  213000
# 1      1       lincoln                     lsv8        2002  143250
# 2      2     chevrolet          silverado2500lt        2002  136731
# 3      3       genesis            g9050ultimate        2017   19500
# 4      4  mercedesbenz               metrisbase        2021    7388
# ..   ...           ...                      ...         ...     ...
# 195  195        toyota           sequoialimited        2008  269885
# 196  196           kia                sorentosx        2011   11649
# 197  197  mercedesbenz               metrisbase        2020   26000
# 198  198          jeep  wranglerunlimitedsahara        2019   62197
# 199  199       bentley        continentalgtbase        2011   18000
#
#             ext_col int_col accident clean_title  age  reliability  \
# 0            yellow    gray        0           1   17     0.215360
# 1            silver   beige        1           1   22    -0.432958
# 2              blue    gray        0           1   22     0.461481
# 3             black   black        0           1    7     0.781159
# 4             black   beige        0           1    3    -0.469551
# ..              ...     ...      ...         ...  ...          ...
# 195            gray   black        0           1   16     0.774392
# 196           black   black        0           1   13     0.546895
# 197           black   black        0           1    4    -0.469551
# 198  blackclearcoat   black        0           1    5    -0.473834
# 199           green   brown        0           1   13     0.000000
#
#                            full_name                  brand_model body_style  \
# 0                2007minicoopersbase              minicoopersbase  hatchback
# 1                    2002lincolnlsv8                  lincolnlsv8        suv
# 2       2002chevroletsilverado2500lt     chevroletsilverado2500lt      truck
# 3           2017genesisg9050ultimate         genesisg9050ultimate      sedan
# 4         2021mercedesbenzmetrisbase       mercedesbenzmetrisbase   cargovan
# ..                               ...                          ...        ...
# 195         2008toyotasequoialimited         toyotasequoialimited        suv
# 196                 2011kiasorentosx                 kiasorentosx        suv
# 197       2020mercedesbenzmetrisbase       mercedesbenzmetrisbase   cargovan
# 198  2019jeepwranglerunlimitedsahara  jeepwranglerunlimitedsahara        suv
# 199     2011bentleycontinentalgtbase     bentleycontinentalgtbase      coupe
#
#        msrp  adjusted_msrp  price_diff  adjusted_price_diff
# 0     17400   26417.533348      -13200        -22217.533348
# 1     47525   83160.610150      -42526        -78161.610150
# 2     26360   46125.485188      -12460        -32225.485188
# 3     66000   84760.619469      -21000        -39760.619469
# 4     39950   46410.875300       57550         51089.124700
# ..      ...            ...         ...                  ...
# 195   50375   73653.482208      -43175        -66453.482208
# 196   23200   32467.389923       -2200        -11467.389923
# 197   35995   43781.334838        3005         -4781.334838
# 198   37400   46050.796406       -3450        -12100.796406
# 199  188675  264042.448002      -99675       -175042.448002
#
# [200 rows x 18 columns]

# %%
xgb_model = xgb.XGBRegressor(enable_categorical=True, tree_method = 'hist')
clf = sk.model_selection.GridSearchCV(xgb_model,{"max_depth": [2, 4, 6], "n_estimators": [50, 100, 200]}, verbose=1, n_jobs=2)
clf.fit(X,y)
# Out:
# Fitting 5 folds for each of 9 candidates, totalling 45 fits
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[18], line 3
#       1 xgb_model = xgb.XGBRegressor(enable_categorical=True, tree_method = 'hist')
#       2 clf = sk.model_selection.GridSearchCV(xgb_model,{"max_depth": [2, 4, 6], "n_estimators": [50, 100, 200]}, verbose=1, n_jobs=2)
# ----> 3 clf.fit(X,y)
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/base.py:1152, in _fit_context.<locals>.decorator.<locals>.wrapper(estimator, *args, **kwargs)
#    1145     estimator._validate_params()
#    1147 with config_context(
#    1148     skip_parameter_validation=(
#    1149         prefer_skip_nested_validation or global_skip_validation
#    1150     )
#    1151 ):
# -> 1152     return fit_method(estimator, *args, **kwargs)
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/model_selection/_search.py:898, in BaseSearchCV.fit(self, X, y, groups, **fit_params)
#     892     results = self._format_results(
#     893         all_candidate_params, n_splits, all_out, all_more_results
#     894     )
#     896     return results
# --> 898 self._run_search(evaluate_candidates)
#     900 # multimetric is determined here because in the case of a callable
#     901 # self.scoring the return type is only known after calling
#     902 first_test_score = all_out[0]["test_scores"]
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/model_selection/_search.py:1422, in GridSearchCV._run_search(self, evaluate_candidates)
#    1420 def _run_search(self, evaluate_candidates):
#    1421     """Search all candidates in param_grid"""
# -> 1422     evaluate_candidates(ParameterGrid(self.param_grid))
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/model_selection/_search.py:845, in BaseSearchCV.fit.<locals>.evaluate_candidates(candidate_params, cv, more_results)
#     837 if self.verbose > 0:
#     838     print(
#     839         "Fitting {0} folds for each of {1} candidates,"
#     840         " totalling {2} fits".format(
#     841             n_splits, n_candidates, n_candidates * n_splits
#     842         )
#     843     )
# --> 845 out = parallel(
#     846     delayed(_fit_and_score)(
#     847         clone(base_estimator),
#     848         X,
#     849         y,
#     850         train=train,
#     851         test=test,
#     852         parameters=parameters,
#     853         split_progress=(split_idx, n_splits),
#     854         candidate_progress=(cand_idx, n_candidates),
#     855         **fit_and_score_kwargs,
#     856     )
#     857     for (cand_idx, parameters), (split_idx, (train, test)) in product(
#     858         enumerate(candidate_params), enumerate(cv.split(X, y, groups))
#     859     )
#     860 )
#     862 if len(out) < 1:
#     863     raise ValueError(
#     864         "No fits were performed. "
#     865         "Was the CV iterator empty? "
#     866         "Were there no candidates?"
#     867     )
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/sklearn/utils/parallel.py:65, in Parallel.__call__(self, iterable)
#      60 config = get_config()
#      61 iterable_with_config = (
#      62     (_with_config(delayed_func, config), args, kwargs)
#      63     for delayed_func, args, kwargs in iterable
#      64 )
# ---> 65 return super().__call__(iterable_with_config)
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/joblib/parallel.py:1952, in Parallel.__call__(self, iterable)
#    1946 # The first item from the output is blank, but it makes the interpreter
#    1947 # progress until it enters the Try/Except block of the generator and
#    1948 # reach the first `yield` statement. This starts the aynchronous
#    1949 # dispatch of the tasks to the workers.
#    1950 next(output)
# -> 1952 return output if self.return_generator else list(output)
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/joblib/parallel.py:1595, in Parallel._get_outputs(self, iterator, pre_dispatch)
#    1592     yield
#    1594     with self._backend.retrieval_context():
# -> 1595         yield from self._retrieve()
#    1597 except GeneratorExit:
#    1598     # The generator has been garbage collected before being fully
#    1599     # consumed. This aborts the remaining tasks if possible and warn
#    1600     # the user if necessary.
#    1601     self._exception = True
#
# File /shared-libs/python3.11/py/lib/python3.11/site-packages/joblib/parallel.py:1707, in Parallel._retrieve(self)
#    1702 # If the next job is not ready for retrieval yet, we just wait for
#    1703 # async callbacks to progress.
#    1704 if ((len(self._jobs) == 0) or
#    1705     (self._jobs[0].get_status(
#    1706         timeout=self.timeout) == TASK_PENDING)):
# -> 1707     time.sleep(0.01)
#    1708     continue
#    1710 # We need to be careful: the job list can be filling up as
#    1711 # we empty it and Python list are not thread-safe by
#    1712 # default hence the use of the lock
#
# KeyboardInterrupt:

# %%
print(clf.best_score_)
print(clf.best_params_)
# Out:
# -1.25976462007868
# {'max_depth': 2, 'n_estimators': 50}
